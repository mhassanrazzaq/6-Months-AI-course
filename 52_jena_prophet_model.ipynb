# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
df = pd.read_csv('jena_climate_2009_2016.csv')
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.75      1.03           1.75     152.3
# 1       1309.80      0.72           1.50     136.1
# 2       1310.24      0.19           0.63     171.6
# 3       1309.19      0.34           0.50     198.0
# 4       1309.00      0.32           0.63     214.3

# %%
df = df[5::72]
df.head()
# Out:
#                Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 5    01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 77   01.01.2009 13:00:00   1000.03     -5.89    267.27        -7.46    88.6
# 149  02.01.2009 01:00:00    999.34     -4.44    268.77        -5.19    94.4
# 221  02.01.2009 13:00:00    998.59     -2.53    270.74        -4.23    88.0
# 293  03.01.2009 01:00:00   1002.39     -5.28    267.70        -6.35    92.1
#
#      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 5            3.33          3.14          0.19       1.96             3.15
# 77           3.93          3.48          0.45       2.17             3.48
# 149          4.39          4.15          0.25       2.58             4.15
# 221          5.07          4.46          0.61       2.78             4.47
# 293          4.12          3.79          0.33       2.36             3.78
#
#      rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 5         1307.86      0.21           0.63     192.7
# 77        1301.73      0.57           1.25     187.3
# 149       1293.47      0.28           1.00     148.1
# 221       1283.22      0.92           1.50     129.4
# 293       1301.68      0.27           1.00     292.8

# %%
df.shape
# Out:
# (5841, 15)

# %%
df.columns
# Out:
# Index(['Date Time', 'p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)',
#        'rh (%)', 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'sh (g/kg)',
#        'H2OC (mmol/mol)', 'rho (g/m**3)', 'wv (m/s)', 'max. wv (m/s)',
#        'wd (deg)'],
#       dtype='object')

# %%
df.rename(columns={'Date Time':'ds',
                   'T (degC)':'y'},
                   inplace=True)

df.head()
# Out:
#                       ds  p (mbar)     y  Tpot (K)  Tdew (degC)  rh (%)  \
# 5    01.01.2009 01:00:00    996.50 -8.05    265.38        -8.78    94.4
# 77   01.01.2009 13:00:00   1000.03 -5.89    267.27        -7.46    88.6
# 149  02.01.2009 01:00:00    999.34 -4.44    268.77        -5.19    94.4
# 221  02.01.2009 13:00:00    998.59 -2.53    270.74        -4.23    88.0
# 293  03.01.2009 01:00:00   1002.39 -5.28    267.70        -6.35    92.1
#
#      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 5            3.33          3.14          0.19       1.96             3.15
# 77           3.93          3.48          0.45       2.17             3.48
# 149          4.39          4.15          0.25       2.58             4.15
# 221          5.07          4.46          0.61       2.78             4.47
# 293          4.12          3.79          0.33       2.36             3.78
#
#      rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 5         1307.86      0.21           0.63     192.7
# 77        1301.73      0.57           1.25     187.3
# 149       1293.47      0.28           1.00     148.1
# 221       1283.22      0.92           1.50     129.4
# 293       1301.68      0.27           1.00     292.8

# %%
df['ds'] = pd.to_datetime(df['ds'], format='%d.%m.%Y %H:%M:%S')

# %%
model = Prophet()

model.fit(df)

future = model.make_future_dataframe(periods = 365)

forecast = model.predict(future)

fig = plot_plotly(model, forecast)

fig.show()
# Out:
# 11:17:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:17:42 - cmdstanpy - INFO - Chain [1] done processing

# %%
df[df.index == 1727]
# Out:
# Empty DataFrame
# Columns: [ds, p (mbar), y, Tpot (K), Tdew (degC), rh (%), VPmax (mbar), VPact (mbar), VPdef (mbar), sh (g/kg), H2OC (mmol/mol), rho (g/m**3), wv (m/s), max. wv (m/s), wd (deg)]
# Index: []

# %%
df[df.index == 1726]
# Out:
# Empty DataFrame
# Columns: [ds, p (mbar), y, Tpot (K), Tdew (degC), rh (%), VPmax (mbar), VPact (mbar), VPdef (mbar), sh (g/kg), H2OC (mmol/mol), rho (g/m**3), wv (m/s), max. wv (m/s), wd (deg)]
# Index: []
